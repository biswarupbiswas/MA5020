# %% [markdown]
# # Lab 1: Introduction to Fluid Flow Simulations
#
# This notebook will introduce you to basic computational fluid dynamics (CFD) concepts.

# %%
import numpy as np
import matplotlib.pyplot as plt

print("Welcome to MA5020 Lab!")
